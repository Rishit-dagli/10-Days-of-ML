# %% [markdown]
# # Clustering, customer Complains
# -[Rishit Dagli](rishit.tech)
#
# ## About Me
#
# [Twitter](https://twitter.com/rishit_dagli)
#
# [GitHub](https://github.com/Rishit-dagli)
#
# [Medium](https://medium.com/@rishit.dagli)

# %% [markdown]
# ## Some imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
import sklearn

# %% [markdown]
# ## Read the data

# %%
complaints = pd.read_csv("Customer Complains/Consumer_Complaints.csv")

# %%
complaints.head(10)
# Out:
#   Date received           Product                             Sub-product  \
# 0    03-12-2014          Mortgage                          Other mortgage
# 1    10-01-2016  Credit reporting                                     NaN
# 2    10/17/2016     Consumer Loan                            Vehicle loan
# 3    06-08-2014       Credit card                                     NaN
# 4    09/13/2014   Debt collection                             Credit card
# 5    11/13/2013          Mortgage  Conventional adjustable mortgage (ARM)
# 6    06/16/2015   Debt collection                                 Medical
# 7    06/15/2015  Credit reporting                                     NaN
# 8    11/13/2015          Mortgage                          Other mortgage
# 9    10/21/2014          Mortgage             Conventional fixed mortgage
#
#                                       Issue  \
# 0  Loan modification,collection,foreclosure
# 1    Incorrect information on credit report
# ...

# %% [markdown]
# ## Some preprocessing

# %% [markdown]
# Let's first see the NA values

# %%
complaints.isna().sum()
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235170
# Issue                                 0
# Sub-issue                        496157
# Consumer Complaint               747196
# Company Public Response          706646
# Company                               0
# State                             12360
# ZIP code                          16718
# Tags                             883422
# Consumer consent provided?       533099
# Submitted via                         0
# Date Sent to Company                  0
# Company Response to Consumer          3
# Timely response?                      0
# Consumer disputed?               256456
# Complaint ID                          0
# Unnamed: 18                     1025010
# dtype: int64

# %% [markdown]
# And there are a lot of NA vaues as our data is very huge we can easily remove them and we wwill do so

# %%
complaints.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer Complaint', 'Company Public Response', 'Company', 'State',
#        'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via',
#        'Date Sent to Company', 'Company Response to Consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID',
#        'Unnamed: 18'],
#       dtype='object')

# %% [markdown]
# Till now you might have guessed that we have 2 major columns, `Product` and `Consumer Complaint` so lets plot them

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
complaints.groupby('Product')['Consumer Complaint'].count().plot.bar(ylim=0)
plt.show()

# %%
np.random.seed(10)
remove_n = 1000000
drop_indices = np.random.choice(complaints.index, remove_n, replace=False)
complaints = complaints.drop(drop_indices)
complaints.shape
# Out:
# (25010, 19)

# %% [markdown]
# Now we will remove our null values and also take the 2 required columns from the dataset

# %%
from io import StringIO
col = ['Product', 'Consumer Complaint']
complaints = complaints[col]
complaints = complaints[pd.notnull(complaints['Consumer Complaint'])]
complaints.columns = ['Product', 'Consumer Complaint']
complaints['category_id'] = complaints['Product'].factorize()[0]
category_id_df = complaints[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)
complaints.head()
# Out:
#                       Product  \
# 947           Debt collection
# 1009         Credit reporting
# 1209  Bank account or service
# 1244              Credit card
# 1268         Credit reporting
#
#                                      Consumer Complaint  category_id
# 947   Called XXXX verified they sent me a letter ver...            0
# 1009  A original debt when into collections from XXX...            1
# 1209  XX/XX/XXXX I received a confirmation of addres...            2
# 1244  I received an application for the American Exp...            3
# 1268  There is an account listed from XXXX XXXX XXXX...            1

# %% [markdown]
# ## Lemmetization, Tokenization and TF-IDF

# %% [markdown]
# First we will do lemmetization using `nltk` WordNetLemmatizer()

# %%
lemmatizer = WordNetLemmatizer() 
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# Let's now clean sentences like remove punctuations

# %%
def sentence_clean(sentence):
    word_list = tokenizer.tokenize(sentence)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %% [markdown]
# Let's now use a TF-ID vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(complaints['Consumer Complaint']).toarray()
labels = complaints.category_id
features.shape
# Out:
# (6769, 19329)

# %% [markdown]
# ## Model selection

# %% [markdown]
# We will use a cool index here, I thought of using this as I had not used it from a long time it's called $chi^2$
#
# Here's an example showing Pearson and $X^2$ or chi squared
#
# ![image.png](attachment:image.png)
#
# $X^2 - X^{'2} = \sum^{k}_{i=1} \frac{x_i^2}{m_i} - \sum^{k}_{i=1} \frac{x_i^2}{m_i^{'}}$

# %% [markdown]
# These are our unigrams and bigrams

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]

# %% [markdown]
# Now we will split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(complaints['Consumer Complaint'], complaints['Product'], random_state = 0)
count_vect = CountVectorizer()

# %% [markdown]
# Let's transform the data with TF-IDF transformer

# %%
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %% [markdown]
# ## Model

# %% [markdown]
# Let's try a sample model to get a hang of this

# %%
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."])))
# Out:
# ['Debt collection']

# %% [markdown]
# So we tried out one prediction and it worked really well, Thats good now let's do an indepth cross validation gridd search with different models and hyper parameters

# %%
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# ...

# %% [markdown]
# Let's create an accuracy plot

# %%
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.681047
# LogisticRegression        0.662135
# MultinomialNB             0.530654
# RandomForestClassifier    0.309055
# Name: accuracy, dtype: float64

# %% [markdown]
# ## Evaluation
# We will now create a heatmap for this

# %%
model = sklearn.svm.SVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, complaints.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.Product.values, yticklabels=category_id_df.Product.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We performed very well here and did a wonderful classification and SVM worked for us. We first lemmatized our data, removed bad characters and punctuations from it. Then, we tokenized our words and finally with a cross validation search we got the best model and received some good results.
