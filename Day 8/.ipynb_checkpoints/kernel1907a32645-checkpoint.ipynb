# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
complaints = pd.read_csv("../input/consumer_complaints/Consumer_Complaints.csv")

# %%
complaints.head(10)

# %%
complaints.isna().sum()

# %%
complaints.columns

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
complaints.groupby('Product')['Consumer Complaint'].count().plot.bar(ylim=0)
plt.show()

# %%
complaints.head()

# %%
complaints.columns

# %%
data = complaints[['Consumer Complaint', 'Product']]

# %%
data = data[pd.notnull(data['Consumer Complaint'])]

# %%
data

# %%
data['category_id'] = data['Product'].factorize()[0]
category_id_df = data[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)
data.head()

# %%
lemmatizer = WordNetLemmatizer() 
tokenizer = RegexpTokenizer(r'\w+')

# %%
def sentence_clean(sentence):
    word_list = tokenizer.tokenize(sentence)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %%
data.shape

# %%
tfidf = TfidfVectorizer(sublinear_tf = True, 
                        min_df=5, 
                        norm='l2', 
                        encoding='latin-1', 
                        ngram_range=(1, 2), 
                        stop_words='english')

features = tfidf.fit_transform(data['Consumer Complaint']).toarray()
labels = df.category_id
features.shape

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
