# %% [markdown]
# # Pneumonia prediction
# -[Rishit Dagli](rishit.tech)
#
# ## About Me
#
# [Twitter](https://twitter.com/rishit_dagli)
#
# [GitHub](https://github.com/Rishit-dagli)
#
# [Medium](https://medium.com/@rishit.dagli)

# %% [markdown]
# If you find the notebook useful and/or learn something from it please upvote it, the complet repository for 10 Days of ML is available here -
#
# https://github.com/Rishit-dagli/10-Days-of-ML
#
# Please Star to show your support
#
# This Notebook is also a part of the 10 Days Of ML Challenge by TFUG Mumbai

# %% [markdown]
# ## Know the dataset
#
# Context
#
# http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5
#
# ![image.png](attachment:image.png)
#
# Figure S6. Illustrative Examples of Chest X-Rays in Patients with Pneumonia, Related to Figure 6
# The normal chest X-ray (left panel) depicts clear lungs without any areas of abnormal opacification in the image. Bacterial pneumonia (middle) typically exhibits a focal lobar consolidation, in this case in the right upper lobe (white arrows), whereas viral pneumonia (right) manifests with a more diffuse ‘‘interstitial’’ pattern in both lungs.
# http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5
#
# Content
#
# The dataset is organized into 3 folders (train, test, val) and contains subfolders for each image category (Pneumonia/Normal). There are 5,863 X-Ray images (JPEG) and 2 categories (Pneumonia/Normal).
#
# Chest X-ray images (anterior-posterior) were selected from retrospective cohorts of pediatric patients of one to five years old from Guangzhou Women and Children’s Medical Center, Guangzhou. All chest X-ray imaging was performed as part of patients’ routine clinical care.
#
# For the analysis of chest x-ray images, all chest radiographs were initially screened for quality control by removing all low quality or unreadable scans. The diagnoses for the images were then graded by two expert physicians before being cleared for training the AI system. In order to account for any grading errors, the evaluation set was also checked by a third expert.
# Acknowledgements
#
# Data: https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# License: CC BY 4.0
#
# Citation: http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5

# %% [markdown]
# ## Some Imports

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

import os
import numpy as np
import pandas as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Let's now see all the availaible files

# %%
print(os.listdir("../input/chest-xray-pneumonia/chest_xray"))

print(os.listdir("../input/chest-xray-pneumonia/chest_xray/train"))

print(os.listdir("../input/chest-xray-pneumonia/chest_xray/train/"))
# Out:
# ['val', '__MACOSX', 'chest_xray', 'train', 'test']
# ['PNEUMONIA', 'NORMAL']
# ['PNEUMONIA', 'NORMAL']

# %% [markdown]
# Let's now take 2 images from the dataset at random and see them, to get an idea about the data

# %%
img_name = 'NORMAL2-IM-0588-0001.jpeg'
img_normal = load_img('../input/chest-xray-pneumonia/chest_xray/train/NORMAL/' + img_name)

print('NORMAL')
plt.imshow(img_normal)
plt.show()
# Out:
# NORMAL

# %%
img_name = 'person63_bacteria_306.jpeg'
img_pneumonia = load_img('../input/chest-xray-pneumonia/chest_xray/train/PNEUMONIA/' + img_name)

print('PNEUMONIA')
plt.imshow(img_pneumonia)
plt.show()
# Out:
# PNEUMONIA

# %% [markdown]
# ## Loading data

# %% [markdown]
# First specify the image height and width

# %%
img_width, img_height = 150, 150

# %% [markdown]
# Now let's specify our directory names and some hyperparameters

# %%
train_data_dir = '../input/chest-xray-pneumonia/chest_xray/train'
validation_data_dir = '../input/chest-xray-pneumonia/chest_xray/val'
test_data_dir = '../input/chest-xray-pneumonia/chest_xray/test'

nb_train_samples = 5217
nb_validation_samples = 17
epochs = 20
batch_size = 16

# %%
input_shape = (img_width, img_height, 3)

# %% [markdown]
# ## Model

# %% [markdown]
# Here is the model I created please feel free to experiment with it and play around and have fun :)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %% [markdown]
# ### Model summaries

# %% [markdown]
# This code peice is something which I have discovered pretty recently and is wonderful, it just prints out all your layers unlike `model.summary()` it does not need to be compiled first

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fce5ada4dd8>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7fce5ada4518>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7fce5ad6c898>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fce5ad6c710>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7fce5ad217f0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7fce5ad217b8>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fce5ad21d68>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7fce5ad38c88>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7fce5ad38c50>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7fce5acc5cc0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fce5acc58d0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7fce5ad38e48>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7fce5acc5da0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fce5acd0d30>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7fce6b7f43c8>]

# %% [markdown]
# This is the input shape our model expects

# %%
model.input
# Out:
# <tf.Tensor 'conv2d_input:0' shape=(None, 150, 150, 3) dtype=float32>

# %% [markdown]
# As we are doing binary classification we will have 1 neuron giving values between 0  and 1

# %%
model.output
# Out:
# <tf.Tensor 'activation_4/Identity:0' shape=(None, 1) dtype=float32>

# %% [markdown]
# I have a pretty good experience with `RMSprop` for images but feel free to experiment with these-
#
# * Adam (does not work that well)
# * Adagrad
# * Adadelta

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %% [markdown]
# ## Getting our data in

# %% [markdown]
# ### Augmentation

# %% [markdown]
# We will first augment our images, made very easy with TensorFlow `ImageDataGenerator`.
#
# It's super simple as simple as just passing in the values and name

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %% [markdown]
# Don't augment the test samples!

# %%
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# Once we are done with augmentation let's load images

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.

# %%
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 16 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 624 images belonging to 2 classes.

# %% [markdown]
# ## Finally train model

# %% [markdown]
# At the time this notebook was made `model.fit_generator` was widely used. It is scheduled to be deprecated, in so case please use `model.fit()`

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Train for 326 steps, validate for 1 steps
# Epoch 1/20
# 326/326 [==============================] - 156s 479ms/step - loss: 0.4104 - accuracy: 0.8227 - val_loss: 0.7886 - val_accuracy: 0.7500
# Epoch 2/20
# 326/326 [==============================] - 140s 429ms/step - loss: 0.2637 - accuracy: 0.8942 - val_loss: 0.7339 - val_accuracy: 0.8125
# Epoch 3/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.2304 - accuracy: 0.9137 - val_loss: 1.3447 - val_accuracy: 0.6250
# Epoch 4/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.2260 - accuracy: 0.9204 - val_loss: 0.5788 - val_accuracy: 0.8125
# Epoch 5/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.2020 - accuracy: 0.9266 - val_loss: 0.4014 - val_accuracy: 0.8125
# Epoch 6/20
# 326/326 [==============================] - 141s 431ms/step - loss: 0.1904 - accuracy: 0.9352 - val_loss: 0.7493 - val_accuracy: 0.6875
# Epoch 7/20
# 326/326 [==============================] - 140s 431ms/step - loss: 0.1966 - accuracy: 0.9308 - val_loss: 0.3346 - val_accuracy: 0.8125
# Epoch 8/20
# 326/326 [==============================] - 140s 430ms/step - loss: 0.1882 - accuracy: 0.9362 - val_loss: 0.7058 - val_accuracy: 0.6875
# Epoch 9/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.1746 - accuracy: 0.9431 - val_loss: 0.4880 - val_accuracy: 0.7500
# Epoch 10/20
# 326/326 [==============================] - 141s 431ms/step - loss: 0.1827 - accuracy: 0.9375 - val_loss: 0.4185 - val_accuracy: 0.8750
# Epoch 11/20
# 326/326 [==============================] - 140s 430ms/step - loss: 0.1742 - accuracy: 0.9413 - val_loss: 0.8807 - val_accuracy: 0.6250
# Epoch 12/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.1777 - accuracy: 0.9436 - val_loss: 1.5521 - val_accuracy: 0.6875
# Epoch 13/20
# 326/326 [==============================] - 141s 434ms/step - loss: 0.1813 - accuracy: 0.9448 - val_loss: 0.7888 - val_accuracy: 0.6875
# Epoch 14/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.1723 - accuracy: 0.9427 - val_loss: 1.9580 - val_accuracy: 0.6250
# Epoch 15/20
# 326/326 [==============================] - 141s 433ms/step - loss: 0.1828 - accuracy: 0.9413 - val_loss: 2.3894 - val_accuracy: 0.6875
# Epoch 16/20
# 326/326 [==============================] - 142s 434ms/step - loss: 0.1794 - accuracy: 0.9434 - val_loss: 0.5978 - val_accuracy: 0.7500
# Epoch 17/20
# 326/326 [==============================] - 141s 431ms/step - loss: 0.1769 - accuracy: 0.9421 - val_loss: 0.5732 - val_accuracy: 0.8125
# Epoch 18/20
# 326/326 [==============================] - 142s 434ms/step - loss: 0.1673 - accuracy: 0.9417 - val_loss: 1.2971 - val_accuracy: 0.7500
# Epoch 19/20
# 326/326 [==============================] - 142s 436ms/step - loss: 0.1820 - accuracy: 0.9459 - val_loss: 0.8763 - val_accuracy: 0.6875
# Epoch 20/20
# 326/326 [==============================] - 141s 432ms/step - loss: 0.1706 - accuracy: 0.9484 - val_loss: 0.8187 - val_accuracy: 0.8125

# %% [markdown]
# ### Save model`s weights

# %% [markdown]
# This step is not at all mandatory but lets make a reference

# %%
model.save_weights('model.h5')

# %% [markdown]
# ## Evaluating our model

# %% [markdown]
# Lets see the accuracy first

# %%
scores = model.evaluate_generator(test_generator)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 89.90%

# %% [markdown]
# And now let's make a plot

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7882ae2a7cbf> in <module>
# ----> 1 plt.plot(history.history['acc'])
#       2 plt.plot(history.history['val_acc'])
#       3 plt.title('Model accuracy')
#       4 plt.ylabel('Accuracy')
#       5 plt.xlabel('Epoch')
#
# KeyError: 'acc'

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Neural Networks, CNNs gave us a very good accuracy, we first augmented our images with the `ImageDataGenerator` and then we loaded our images into the runtime. We then created a model which was pretty good.
